# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16346 entries, 0 to 16504
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           16346 non-null  float64
#  1   latitude            16346 non-null  float64
#  2   housing_median_age  16346 non-null  float64
#  3   total_rooms         16346 non-null  float64
#  4   total_bedrooms      16346 non-null  float64
#  5   population          16346 non-null  float64
#  6   households          16346 non-null  float64
#  7   median_income       16346 non-null  float64
#  8   median_house_value  16346 non-null  float64
#  9   ocean_proximity     16346 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.9+ MB

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  16346.000000  16346.000000        16346.000000  16346.000000
# mean    -119.131895     35.255423           29.262817   2638.149027
# std        1.923161      2.086936           12.797605   2254.848860
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.240000     33.870000           19.000000   1442.000000
# 50%     -118.300000     34.100000           30.000000   2105.000000
# 75%     -117.890000     37.700000           38.000000   3107.750000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    16346.000000  16346.000000  16346.000000   16346.000000
# mean       544.269057   1437.523676    503.790775       3.800959
# std        435.969366   1162.385746    393.706456       1.870872
# min          1.000000      3.000000      1.000000       0.499900
# 25%        297.000000    793.000000    281.000000       2.523800
# 50%        436.000000   1168.000000    410.000000       3.477300
# 75%        648.750000   1726.000000    603.000000       4.641425
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        16346.000000
# mean        202141.662547
# std         113651.650555
# min          14999.000000
# 25%         118200.000000
# 50%         173900.000000
# 75%         253675.000000
# max         500001.000000

# %%
data.dropna()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 16500    -121.04     37.78                32.0       2916.0           528.0
# 16501    -121.06     37.86                24.0       1713.0           328.0
# 16502    -121.13     37.74                31.0        677.0           144.0
# 16503    -121.13     37.74                28.0        409.0           104.0
# 16504    -121.12     37.73                35.0       1107.0           227.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 16500      1466.0       473.0         2.5643            200000.0
# 16501      1258.0       324.0         2.6830            169400.0
# 16502       523.0       159.0         2.4598             97100.0
# 16503       244.0        98.0         3.4643             90900.0
# 16504       573.0       210.0         2.3924            102200.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 16500          INLAND
# 16501          INLAND
# 16502          INLAND
# 16503          INLAND
# 16504          INLAND
#
# [16346 rows x 10 columns]

# %%
data.dropna(inplace=True)
# Out:
# C:\Users\SUDHESH.MN\AppData\Local\Temp\ipykernel_13340\1368182302.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16346 entries, 0 to 16504
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           16346 non-null  float64
#  1   latitude            16346 non-null  float64
#  2   housing_median_age  16346 non-null  float64
#  3   total_rooms         16346 non-null  float64
#  4   total_bedrooms      16346 non-null  float64
#  5   population          16346 non-null  float64
#  6   households          16346 non-null  float64
#  7   median_income       16346 non-null  float64
#  8   median_house_value  16346 non-null  float64
#  9   ocean_proximity     16346 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.9+ MB

# %%
from sklearn.model_selection import train_test_split
x=data.drop(['median_house_value'],axis=1)
y=data['median_house_value']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
train_data=x_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1206     -121.71     39.41                22.0       1814.0           342.0
# 9174     -118.52     34.39                21.0       5477.0          1275.0
# 14071    -117.12     32.76                26.0       1221.0           331.0
# 4359     -118.37     34.08                22.0       3008.0           938.0
# 12716    -121.37     38.60                35.0       3137.0           544.0
# ...          ...       ...                 ...          ...             ...
# 1819     -122.32     37.94                47.0       1911.0           283.0
# 14232    -117.04     32.68                11.0       1875.0           357.0
# 10556    -117.71     33.63                16.0       1641.0           354.0
# 3665     -118.37     34.22                17.0       1787.0           463.0
# 1521     -122.07     37.91                28.0       1731.0           295.0
#
#        population  households  median_income ocean_proximity  \
# 1206        941.0       323.0         2.1728          INLAND
# 9174       3384.0      1222.0         3.6625       <1H OCEAN
# 14071       620.0       296.0         2.4821      NEAR OCEAN
# 4359       1224.0       816.0         3.2149       <1H OCEAN
# 12716      1312.0       549.0         3.7880          INLAND
# ...           ...         ...            ...             ...
# 1819        697.0       275.0         6.2712        NEAR BAY
# 14232      1014.0       386.0         4.3750      NEAR OCEAN
# 10556       945.0       318.0         3.4261       <1H OCEAN
# 3665       1671.0       448.0         3.5521       <1H OCEAN
# 1521        810.0       295.0         5.0391        NEAR BAY
#
#        median_house_value
# 1206              59400.0
# 9174             228100.0
# 14071            123600.0
# 4359             300000.0
# 12716            136800.0
# ...                   ...
# 1819             267700.0
# 14232            115000.0
# 10556            219700.0
# 3665             151500.0
# 1521             259800.0
#
# [13076 rows x 10 columns]

# %%
train_data.hist()
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
#train_data.drop(['ocean_proximity'],axis=1,inplace=True)

# %%
#train_data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924804           -0.108526     0.031987
# latitude            -0.924804  1.000000            0.011997    -0.034493
# housing_median_age  -0.108526  0.011997            1.000000    -0.314026
# total_rooms          0.031987 -0.034493           -0.314026     1.000000
# total_bedrooms       0.061249 -0.068762           -0.272065     0.946098
# population           0.112490 -0.140783           -0.242355     0.862655
# households           0.058371 -0.091146           -0.241394     0.931405
# median_income       -0.012076 -0.082402           -0.116894     0.200936
# median_house_value  -0.042034 -0.146973            0.110378     0.154363
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.061249    0.112490    0.058371      -0.012076
# latitude                 -0.068762   -0.140783   -0.091146      -0.082402
# housing_median_age       -0.272065   -0.242355   -0.241394      -0.116894
# total_rooms               0.946098    0.862655    0.931405       0.200936
# total_bedrooms            1.000000    0.895908    0.974145      -0.030004
# population                0.895908    1.000000    0.931385      -0.009977
# households                0.974145    0.931385    1.000000      -0.000504
# median_income            -0.030004   -0.009977   -0.000504       1.000000
# median_house_value        0.048092   -0.025737    0.067593       0.689892
#
#                     median_house_value
# longitude                    -0.042034
# latitude                     -0.146973
# housing_median_age            0.110378
# total_rooms                   0.154363
# total_bedrooms                0.048092
# population                   -0.025737
# households                    0.067593
# median_income                 0.689892
# median_house_value            1.000000

# %%
plt.figure(figsize=(15,8))
plt.title("Heatmap")
sns.heatmap(train_data.select_dtypes(include=['int64','float64']).corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: title={'center': 'Heatmap'}>

# %%
train_data['total_rooms']=np.log(train_data['total_rooms']+1)
train_data['total_bedrooms']=np.log(train_data['total_bedrooms']+1)
train_data['population']=np.log(train_data['population']+1)
train_data['households']=np.log(train_data['households']+1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1206     -121.71     39.41                22.0     7.503841        5.837730
# 9174     -118.52     34.39                21.0     8.608495        7.151485
# 14071    -117.12     32.76                26.0     7.108244        5.805135
# 4359     -118.37     34.08                22.0     8.009363        6.844815
# 12716    -121.37     38.60                35.0     8.051341        6.300786
# ...          ...       ...                 ...          ...             ...
# 1819     -122.32     37.94                47.0     7.555905        5.648974
# 14232    -117.04     32.68                11.0     7.536897        5.880533
# 10556    -117.71     33.63                16.0     7.403670        5.872118
# 3665     -118.37     34.22                17.0     7.488853        6.139885
# 1521     -122.07     37.91                28.0     7.457032        5.690359
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 1206     6.848005    5.780744         2.1728             59400.0      False
# 9174     8.127109    7.109062         3.6625            228100.0       True
# 14071    6.431331    5.693732         2.4821            123600.0      False
# 4359     7.110696    6.705639         3.2149            300000.0       True
# 12716    7.180070    6.309918         3.7880            136800.0      False
# ...           ...         ...            ...                 ...        ...
# 1819     6.548219    5.620401         6.2712            267700.0      False
# 14232    6.922644    5.958425         4.3750            115000.0      False
# 10556    6.852243    5.765191         3.4261            219700.0       True
# 3665     7.421776    6.107023         3.5521            151500.0       True
# 1521     6.698268    5.690359         5.0391            259800.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 1206     True   False     False       False
# 9174    False   False     False       False
# 14071   False   False     False        True
# 4359    False   False     False       False
# 12716    True   False     False       False
# ...       ...     ...       ...         ...
# 1819    False   False      True       False
# 14232   False   False     False        True
# 10556   False   False     False       False
# 3665    False   False     False       False
# 1521    False   False      True       False
#
# [13076 rows x 14 columns]

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1206     -121.71     39.41                22.0     7.503841        5.837730
# 9174     -118.52     34.39                21.0     8.608495        7.151485
# 14071    -117.12     32.76                26.0     7.108244        5.805135
# 4359     -118.37     34.08                22.0     8.009363        6.844815
# 12716    -121.37     38.60                35.0     8.051341        6.300786
# ...          ...       ...                 ...          ...             ...
# 1819     -122.32     37.94                47.0     7.555905        5.648974
# 14232    -117.04     32.68                11.0     7.536897        5.880533
# 10556    -117.71     33.63                16.0     7.403670        5.872118
# 3665     -118.37     34.22                17.0     7.488853        6.139885
# 1521     -122.07     37.91                28.0     7.457032        5.690359
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 1206     6.848005    5.780744         2.1728             59400.0      False
# 9174     8.127109    7.109062         3.6625            228100.0       True
# 14071    6.431331    5.693732         2.4821            123600.0      False
# 4359     7.110696    6.705639         3.2149            300000.0       True
# 12716    7.180070    6.309918         3.7880            136800.0      False
# ...           ...         ...            ...                 ...        ...
# 1819     6.548219    5.620401         6.2712            267700.0      False
# 14232    6.922644    5.958425         4.3750            115000.0      False
# 10556    6.852243    5.765191         3.4261            219700.0       True
# 3665     7.421776    6.107023         3.5521            151500.0       True
# 1521     6.698268    5.690359         5.0391            259800.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 1206     True   False     False       False
# 9174    False   False     False       False
# 14071   False   False     False        True
# 4359    False   False     False       False
# 12716    True   False     False       False
# ...       ...     ...       ...         ...
# 1819    False   False      True       False
# 14232   False   False     False        True
# 10556   False   False     False       False
# 3665    False   False     False       False
# 1521    False   False      True       False
#
# [13076 rows x 14 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True,cmap='YlGnBu')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='latitude',y='longitude',data=train_data,hue='median_house_value',palette='coolwarm')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio']=train_data['total_bedrooms']/train_data['total_rooms']

# %%
train_data['households_rooms']=train_data['total_rooms']/train_data['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True,cmap='YlGnBu')
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
x_train,y_train=train_data.drop(['median_house_value'],axis=1),train_data['median_house_value']
scaler=StandardScaler()
x_train_s=scaler.fit_transform(x_train)

# %%
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
test_data=x_test.join(y_test)
test_data['total_rooms']=np.log(test_data['total_rooms']+1)
test_data['total_bedrooms']=np.log(test_data['total_bedrooms']+1)
test_data['population']=np.log(test_data['population']+1)
test_data['households']=np.log(test_data['households']+1)
test_data=test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)
test_data['bedroom_ratio']=test_data['total_bedrooms']/test_data['total_rooms']
test_data['households_rooms']=test_data['total_rooms']/test_data['households']

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11207    -117.92     33.83                52.0     7.323171        5.710427
# 3827     -118.46     34.20                22.0     8.487970        7.208600
# 8027     -118.12     33.83                44.0     7.446001        5.752573
# 16081    -122.49     37.74                52.0     7.741968        6.126869
# 16439    -121.29     38.14                27.0     6.729824        4.890349
# ...          ...       ...                 ...          ...             ...
# 6645     -118.15     34.17                36.0     6.836259        5.638355
# 14396    -117.25     32.75                32.0     8.175266        6.945051
# 14020    -117.16     32.74                27.0     7.756195        6.405228
# 2607     -124.01     40.97                21.0     7.322510        5.768321
# 10046    -120.99     39.22                16.0     7.311886        5.620401
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 11207    6.752270    5.683580         3.6042            166400.0       True
# 3827     7.832014    7.138073         3.0893            205600.0       True
# 8027     6.539586    5.683580         4.3594            221300.0       True
# 16081    7.051856    6.052089         4.5744            315200.0      False
# 16439    5.717028    4.897840         3.8750            127400.0      False
# ...           ...         ...            ...                 ...        ...
# 6645     6.932448    5.707110         1.0846            146400.0       True
# 14396    7.457032    6.841615         2.2017            208300.0      False
# 14020    6.890609    6.381816         3.1921            261500.0      False
# 2607     6.850126    5.710427         3.5380            102700.0       True
# 10046    6.603944    5.497168         2.8942            182500.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  households_rooms
# 11207   False   False     False       False       0.779775          1.288479
# 3827    False   False     False       False       0.849273          1.189112
# 8027    False   False     False       False       0.772572          1.310090
# 16081   False   False     False        True       0.791384          1.279222
# 16439    True   False     False       False       0.726668          1.374039
# ...       ...     ...       ...         ...            ...               ...
# 6645    False   False     False       False       0.824772          1.197850
# 14396   False   False     False        True       0.849520          1.194932
# 14020   False   False     False        True       0.825821          1.215359
# 2607    False   False     False       False       0.787752          1.282305
# 10046    True   False     False       False       0.768666          1.330119
#
# [3270 rows x 16 columns]

# %%
x_test, y_test = test_data.drop(['median_house_value'], axis=1), test_data['median_house_value']
x_test_s=scaler.transform(x_test)

# %%
reg.score(x_test,y_test)
# Out:
# 0.6652023619851364

# %%
from sklearn.ensemble import RandomForestRegressor
forest=RandomForestRegressor()
forest.fit(x_train_s,y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test_s,y_test)
# Out:
# 0.8088012714147212

# %%
from sklearn.model_selection import GridSearchCV
forest = RandomForestRegressor()
param_grid = {
"n_estimators": [100, 200, 300],
"min_samples_split": [2, 4],
"max_depth": [None, 4, 8]
}
grid_search = GridSearchCV(forest, param_grid, cv=5,
scoring="neg_mean_squared_error",
return_train_score=True)
grid_search.fit(x_train_s, y_train)

# %%
grid_search.best_estimator.score(x_test_s,y_test)
